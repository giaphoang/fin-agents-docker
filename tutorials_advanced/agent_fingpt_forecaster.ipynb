# %% [markdown]
# # FinGPT-Forecaster Re-implemented with FinRobot

# %% [markdown]
# In this demo, we set up an agent to emulate the behavior of model in the fingpt-forecaster project with AutoGen, which takes a company's ticker symbol, recent basic financials and market news as input and predict its stock movements.
#
# For detail of the original project, check out  [FinGPT-Forecaster](https://github.com/AI4Finance-Foundation/FinGPT/tree/master/fingpt/FinGPT_Forecaster)!  🔥[Demo](https://huggingface.co/spaces/FinGPT/FinGPT-Forecaster), [Medium Blog](https://medium.datadriveninvestor.com/introducing-fingpt-forecaster-the-future-of-robo-advisory-services-50add34e3d3c) & [Model](https://huggingface.co/FinGPT/fingpt-forecaster_dow30_llama2-7b_lora) on Huggingface🤗!

# %%
import autogen
from autogen.cache import Cache

from finrobot.utils import get_current_date, register_keys_from_json
from finrobot.data_source import FinnHubUtils, YFinanceUtils

# %% [markdown]
# After importing all the necessary packages and functions, we first instantiate a market analysis assistant and a user proxy using the agent classes defined by AutoGen. We also need the config for OpenAI & Finnhub here.
# - for openai configuration, rename OAI_CONFIG_LIST_sample to OAI_CONFIG_LIST and replace the api keys
# - for finnhub configuration, rename config_api_keys_sample to config_api_keys and replace the api keys

# %%
# Read OpenAI API keys from a JSON file
config_list = autogen.config_list_from_json(
    "../OAI_CONFIG_LIST",
    filter_dict={"model": ["gpt-4-0125-preview"]},
)
llm_config = {"config_list": config_list, "timeout": 120, "temperature": 0}

# Register FINNHUB API keys
register_keys_from_json("../config_api_keys")

# %%
analyst = autogen.AssistantAgent(
    name="Market_Analyst",
    system_message="As a Market Analyst, one must possess strong analytical and problem-solving abilities, collect necessary financial information and aggregate them based on client's requirement."
    "For coding tasks, only use the functions you have been provided with. Reply TERMINATE when the task is done.",
    llm_config=llm_config,
)

user_proxy = autogen.UserProxyAgent(
    name="User_Proxy",
    is_termination_msg=lambda x: x.get("content", "") and x.get(
        "content", "").endswith("TERMINATE"),
    human_input_mode="NEVER",
    max_consecutive_auto_reply=10,
    code_execution_config={
        "work_dir": "coding",
        "use_docker": False,
    },  # Please set use_docker=True if docker is available to run the generated code. Using docker is safer than running the generated code directly.
)

# %% [markdown]
# Then we register our predefined functions with the userproxy.
#
# Following our implementation with the fingpt-forecaster, we combined news/financials calls to the Finnhub API and stock data calls to the YFinance API.

# %%
from finrobot.toolkits import register_toolkits

tools = [
    {
        "function": FinnHubUtils.get_company_profile,
        "name": "get_company_profile",
        "description": "get a company's profile information"
    },
    {
        "function": FinnHubUtils.get_company_news,
        "name": "get_company_news",
        "description": "retrieve market news related to designated company"
    },
    {
        "function": FinnHubUtils.get_basic_financials,
        "name": "get_financial_basics",
        "description": "get latest financial basics for a designated company"
    },
    {
        "function": YFinanceUtils.get_stock_data,
        "name": "get_stock_data",
        "description": "retrieve stock price data for designated ticker symbol"
    }
]
register_toolkits(tools, analyst, user_proxy)

# %% [markdown]
# Start the conversation, asking the agent to call all the functions, and see how it aggregates all the information and leads to the conclusion.

# %%
company = "Tesla"
# company = "APPLE"

with Cache.disk() as cache:
    # start the conversation
    user_proxy.initiate_chat(
        analyst,
        message=f"Use all the tools provided to retrieve information available for {company} upon {get_current_date()}. Analyze the positive developments and potential concerns of {company} "
        "with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. "
        f"Then make a rough prediction (e.g. up/down by 2-3%) of the {company} stock price movement for next week. Provide a summary analysis to support your prediction.",
        cache=cache,
    )
# Out:
# User_Proxy (to Market_Analyst):
#
# Use all the tools provided to retrieve information available for Tesla upon 2025-04-20. Analyze the positive developments and potential concerns of Tesla with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. Then make a rough prediction (e.g. up/down by 2-3%) of the Tesla stock price movement for next week. Provide a summary analysis to support your prediction.
#
# --------------------------------------------------------------------------------
# Market_Analyst (to User_Proxy):
#
# ***** Suggested tool call (call_u3EfG97hdd0odJVM3pA7Vmcx): get_company_profile *****
# Arguments:
# {"symbol": "TSLA"}
# ************************************************************************************
# ***** Suggested tool call (call_qAKZngnr9I1q9Ju8ZBQZ8Uzx): get_company_news *****
# Arguments:
# {"symbol": "TSLA", "start_date": "2025-04-13", "end_date": "2025-04-20"}
# *********************************************************************************
# ***** Suggested tool call (call_3Di28qb2Cufnp2m0EHxmGRQ9): get_financial_basics *****
# Arguments:
# {"symbol": "TSLA", "selected_columns": null}
# *************************************************************************************
# ***** Suggested tool call (call_rKMRH2pLcJxtBOYyvC2Msyer): get_stock_data *****
# Arguments:
# {"symbol": "TSLA", "start_date": "2025-04-13", "end_date": "2025-04-20"}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_company_profile...
# Call ID: call_u3EfG97hdd0odJVM3pA7Vmcx
# Input arguments: {'symbol': 'TSLA'}
# Finnhub client initialized
#
# >>>>>>>> EXECUTING FUNCTION get_company_news...
# Call ID: call_qAKZngnr9I1q9Ju8ZBQZ8Uzx
# Input arguments: {'symbol': 'TSLA', 'start_date': '2025-04-13', 'end_date': '2025-04-20'}
# Finnhub client initialized
#
# >>>>>>>> EXECUTING FUNCTION get_financial_basics...
# Call ID: call_3Di28qb2Cufnp2m0EHxmGRQ9
# Input arguments: {'symbol': 'TSLA', 'selected_columns': None}
# Finnhub client initialized
#
# >>>>>>>> EXECUTING FUNCTION get_stock_data...
# Call ID: call_rKMRH2pLcJxtBOYyvC2Msyer
# Input arguments: {'symbol': 'TSLA', 'start_date': '2025-04-13', 'end_date': '2025-04-20'}
# User_Proxy (to Market_Analyst):
#
# ***** Response from calling tool (call_u3EfG97hdd0odJVM3pA7Vmcx) *****
# [Company Introduction]:
#
# Tesla Inc is a leading entity in the Automobiles sector. Incorporated and publicly traded since 2013-03-06, the company has established its reputation as one of the key players in the market. As of today, Tesla Inc has a market capitalization of 776370.71 in USD, with 3216.52 shares outstanding.
#
# Tesla Inc operates primarily in the US, trading under the ticker TSLA on the NASDAQ NMS - GLOBAL MARKET. As a dominant force in the Automobiles space, the company continues to innovate and drive progress within the industry.
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_qAKZngnr9I1q9Ju8ZBQZ8Uzx) *****
#              date                                                                                       headline                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               summary
# 0  20250413060002                                                        Taking a deeper look at humanoid robots                                                                                                                                                                                                                                                        Investing.com -- The global race to develop humanoid robots is accelerating, with Macquarie analysts seeing the potential for this sector to reach a total addressable market (TAM) of $1.7 trillion by 2050, on par with today’s global light vehicle market.
# 1  20250414064658               Tesla Vs. BYD: Tesla Brand 'Destruction' Takes Toll As Fast-Charging Rival Booms                                                                                                                                                                                                                                                                                                                                                                         TSLA stock is near 2025 lows with Q1 earnings due amid Elon Musk brand "destruction." BYD earnings are surging amid multiple growth drivers..
# 2  20250414105608  Justice Department charges man with arson at New Mexico Tesla dealership and GOP headquarters                                                                                                                                                                                                                                                                                                                     WASHINGTON — The Justice Department has charged a man with vandalizing a Tesla dealership in New Mexico and setting fire to the headquarters of the state Republican Party, according to court...
# 3  20250415093100                               Tesla Q1 Earnings Likely to Disappoint Investors: Things to Note                                                                                                                                                                                                                                                                                                                                                              The Zacks Consensus Estimate for TSLA's to-be-reported quarter's earnings and revenues is pegged at 45 cents per share and $21.85 billion, respectively.
# 4  20250415144112                Trump Ally Marjorie Taylor Greene Bought Tesla, Amazon, Blackstone Before Rally  (Bloomberg) -- Representative Marjorie Taylor Greene sold US Treasuries and bought stakes in Amazon.com Inc., Blackstone Inc. and Tesla Inc. the day before President Donald Trump put a 90-day pause on retaliatory tariffs and prompted a market rally.Most Read from BloombergHow Did This Suburb Figure Out Mass Transit?Trump Signs Executive Orders on Federal Purchasing, Office SpaceEven Oslo Has an Air Quality ProblemLA County Floats Leaner Budget Burdened by Fire and Legal Costs$15 Million Fund Bet
# 5  20250415145057                                    Tesla, Inc. (TSLA): Seen as an ‘Embodied AI Secular Winner’                                                                                                                                                                We recently published a list of 10 AI Stocks to Watch Amid Market Volatility. In this article, we are going to take a look at where Tesla, Inc. (NASDAQ:TSLA) stands against other AI stocks to watch amid market volatility. The uncertain macroeconomic environment is diminishing investors’ readiness to pay high prices for stocks related to […]
# 6  20250416141049                                          Tesla: A Visionary Company Relying Too Much On Vision
# 7  20250416141049                                          Tesla: A Visionary Company Relying Too Much On Vision
# 8  20250416213121                                                                                    BABY BOOMER                                                                                                                                                                                                                                                                                                                  The mother of one of Elon Musk's 14 children has told the Wall Street Journal the Tesla chief wants to have enough children to reach legion-level before the apocalypse and has considered hiring...
# 9  20250418150430                                 Is Tesla, Inc. (TSLA) Among the Best EV Stocks To Buy in 2025?                                                                                                                                                                                                   We recently published a list of 12 Best EV Stocks To Buy in 2025. In this article, we are going to take a look at where Tesla, Inc. (NASDAQ:TSLA) stands against other best EV stocks to buy in 2025. Electric cars, often known as electric vehicles or EVs, are automobiles powered by electricity instead of […]
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_3Di28qb2Cufnp2m0EHxmGRQ9) *****
# Error: list index out of range
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_rKMRH2pLcJxtBOYyvC2Msyer) *****
#                                  Open        High         Low       Close     Volume  Dividends  Stock Splits
# Date
# 2025-04-14 00:00:00-04:00  258.359985  261.799988  245.929993  252.350006  100135200        0.0           0.0
# 2025-04-15 00:00:00-04:00  249.910004  258.750000  247.539993  254.110001   79594300        0.0           0.0
# 2025-04-16 00:00:00-04:00  247.610001  251.970001  233.889999  241.550003  112378700        0.0           0.0
# 2025-04-17 00:00:00-04:00  243.470001  244.339996  237.679993  241.369995   83404800        0.0           0.0
# **********************************************************************
#
# --------------------------------------------------------------------------------
# Market_Analyst (to User_Proxy):
#
# ### Positive Developments for Tesla:
#
# 1. **AI and EV Market Leadership**: Tesla is recognized as an 'Embodied AI Secular Winner' and is among the best EV stocks to buy in 2025. This highlights Tesla's strong positioning in the rapidly growing AI and electric vehicle (EV) markets, which are expected to drive future growth and innovation in the automotive industry.
#
# 2. **Investment Interest**: The purchase of Tesla stocks by notable figures, such as Marjorie Taylor Greene, ahead of significant market movements, indicates confidence in Tesla's market performance and its potential for future growth. This could signal strong investor sentiment and potential for stock price appreciation.
#
# ### Potential Concerns for Tesla:
#
# 1. **Brand Challenges and Competition**: Tesla faces brand 'destruction' issues and intense competition from fast-charging rivals like BYD, which is experiencing surging earnings. This could impact Tesla's market share and profitability if not addressed effectively.
#
# 2. **Financial Performance Concerns**: The Q1 earnings for Tesla are likely to disappoint investors, with earnings and revenue estimates suggesting potential challenges ahead. This could affect investor confidence and stock price in the short term.
#
# 3. **Legal and Public Relations Issues**: The arson at a New Mexico Tesla dealership and the negative publicity surrounding Elon Musk's personal life and ambitions could pose reputational risks and distract from business operations.
#
# ### Stock Price Movement Prediction for Next Week:
#
# Given the mixed developments, with significant positive recognition in AI and EV sectors but concerns over brand image, competition, and financial performance, the Tesla stock price might experience volatility in the short term. However, the strong positioning in key growth markets could mitigate some negative impacts.
#
# **Prediction**: The stock price might see a slight **downward movement** by **1-2%** next week. This is based on the recent stock performance showing a downward trend in the stock price from $258.36 to $241.37 over the past week, combined with the potential investor concerns over the upcoming earnings and brand challenges.
#
# ### Summary Analysis:
#
# Tesla remains a leader in the AI and EV markets, which positions it well for long-term growth. However, short-term challenges related to brand perception, competition, and financial performance could impact investor sentiment and stock price. The company's ability to navigate these challenges and capitalize on its strengths in innovation and market positioning will be crucial for its stock performance in the near term.
#
# --------------------------------------------------------------------------------
# User_Proxy (to Market_Analyst):
#
#
#
# --------------------------------------------------------------------------------
# Market_Analyst (to User_Proxy):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (0de145f3-60d1-461a-a05f-3b14fece61b3): Termination message condition on agent 'User_Proxy' met
